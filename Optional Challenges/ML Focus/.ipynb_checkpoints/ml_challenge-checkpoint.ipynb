# %% [markdown]
# # ML Challenge (Optional)

# %% [markdown]
# Train, test, optimize, and analyze the performance of a classification model using a methodology of your choice for the randomly generated moons dataset.
#
# You are not being evaluated for the performance of your model. Instead, we are interested in whether you can implement a simple but rigorous ML workflow.
#
# Show all of your work in this notebook.

# %%
# you are free to use any package you deem fit
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %% [markdown]
# ## Dataset

# %% [markdown]
# I started off by loading in the data and visualizing the training data. I wasn't quite sure how to approach this dataset at first, since there are no names to the features, and it's unclear what the response variable is meant to be (what do 0 and 1 correspond to). However, I gave it my best shot anyways. For the purposes of this exercise, I referred to the features as 'feature 1' and 'feature 2' and to the repsonse variable as simply 'output variable.' The two features are relatively small floating point numbers centered roughly around zero (with some negative values and some positive).

# %%
# DO NOT MODIFY
from sklearn.datasets import make_moons
X, Y = make_moons(random_state=42, n_samples=(50, 450), noise=0.25)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Visualize the training set

figure = plt.figure(figsize=(10, 10))
cm = plt.cm.RdBu
cm_bright = ListedColormap(['#FF0000', '#006400'])
ax = plt.subplot(1,1,1)
# training points
ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright)
plt.xlabel('feature 1')
plt.ylabel('feature 2')
# Out:
# Text(0, 0.5, 'feature 2')

# %% [markdown]
# It seems from visualizing this data set that the majority of the values are classified as 1. It also seems that having a higher positive value for feature 1 and a lower negative value for feature 2 (i.e., towards the bottom right corner) corresponds to an output value of 1.

# %% [markdown]
# ## Training

# %%
from sklearn import svm

model = svm.SVC(kernel='linear')
model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# ## Testing / Optimization

# %% [markdown]
# I chose an SVM (Support-Vector Machine) classifier to construct my model.

# %%
from sklearn import svm

model = svm.SVC(kernel='linear')
model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# ## Performance Analysis

# %% [markdown]
# The R^2 value was quite high, suggesting strong performance.

# %%
# R^2 value
print("R^2 value of this model: " + str(model.score(X_test, y_test)))
# Out:
# R^2 value of this model: 0.9266666666666666

# %%
# mean error
print("Mean error of this model: " + str(np.mean(model.predict(X_test)-y_test)))
# Out:
# Mean error of this model: 0.03333333333333333

# %%
f = plt.figure(figsize=(12,4))
plt.scatter(X_train[:,0], y_train, color = "purple")
plt.scatter(X_train[:,1], model.predict(X_train), color = "orange")

plt.legend(['True Training','Predicted Training'])
plt.ylabel('Output variable')
plt.title("Model Behavior On Training Set")
# Out:
# Text(0.5, 1.0, 'Model Behavior On Training Set')

# %% [markdown]
# #### Model coefficients (i.e., which features contributed the most to making the prediction?)

# %%
plt.figure(figsize=(12,8))
# Top 10 most important features
pd.Series(abs(model.coef_[0]), index=['feature 1', 'feature 2']).nlargest(20).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# It seems from this graph that feature 2 contributed more to predicting whether or not the moon output variable was 0 or 1.
